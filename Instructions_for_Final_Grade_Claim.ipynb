# %% [markdown]
# <a href="https://colab.research.google.com/github/spencerleewilliams/cse380-notebooks/blob/master/Instructions_for_Final_Grade_Claim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions for Final Grade Claim
# ## CSE 380 Discrete Mathematics II
# ### Winter 2021

# %% [markdown]
# ## Refresher

# %% [markdown]
# This was posted to the class chat channel before the second grade claim:
#
# > All of you aspire to at least pass this class. That means successfully claiming a C or better for your final grade claim. Recognizing that there is a redemption opportunity during the last 5 weeks of the semester (the final grade claim period), here is what you should do to prepare for your second grade claim meeting:
#
# > Acknowledging that you are a dedicated disciple of Jesus Christ and therefore would never deceive yourself or me about the type of student you have been striving to be during the past four weeks, know that
#
# > a C student
#
# > does what's required, mostly, but maybe not well, and has high participation in the Teach One Another (DPC, CDL, Discussion Forum) activities, but low Problem Solving as manifest in the Reading Quizzes and the Ponder and Prove assignments;
#
# > a B student
#
# > does what's required, does it well, and has high participation in the Teach One Another (DPC, CDL, Discussion Forum) activities, and high Problem Solving as manifest in the Reading Quizzes and the Ponder and Prove assignments;
#
# > an A student is like a B student, except he or she
#
# > 1. Does not need to be "commanded in all things". [Doctrine and Covenants 58:26](https://www.churchofjesuschrist.org/study/scriptures/dc-testament/dc/58.26?lang=eng#p26#26)
# 2. Goes above and beyond what's required.
# 3. Diligently applies the gersy principle.
# 4. Does not need to be told to take this or that GPAO.
# 5. Takes initiative in serving other students.
# 6. Helps classmates learn.
# 7. Studies other topics related to the main topic of the week.
# 8. Makes connections to other areas of learning.
# 9. Applies learning to life.
# 10. Reports evidence of these behaviors.
#
# > That doesn't mean doing all of these every week. But it does mean doing some of them each week, especially the reporting.
#
# > Please come prepared to your grade claim meeting having prayed deeply to the Lord about the appropriateness of the grade you will be claiming, having been open to hearing His voice, having five tabs open in your browser scrolled to the evidences that you think most clearly show you to be the type of student you're claiming to be, and having pondered on and decided on a plan for improvement that you will share with me.

# %% [markdown]
# ## What Is Different?

# %% [markdown]
# Instead of having five tabs open in your browser, you will have a **single** tab open on a **single** document.
#
# Create this document as a .pdf or .ipynb notebook --- preferably the latter --- and be sure you have done the following:
#
# 1. Name it ```14_1_My_Final_Grade_Claim_for_W21.ipynb``` (or ```14_1_My_Final_Grade_Claim_for_W21.pdf```).
# 2. At the top of your document, put a copy of the flowchart image below, with the **leaf $\equiv$ claimed grade** highlighted.
# 3. Immediately following that, put links to two or three different cells in your Colab-hosted-from-github notebooks from Week 09 on. These should be links to your "Top 3" evidences --- showing what you were the most excited about to learn or do.
# 4. If you are claiming an A, instead of a third link, in a separate document section list and briefly describe specific instances over the last five weeks where you went **above and beyond**.

# %% [markdown]
# ![final-grade-claim-decision.png](data:image/png;base64,...)

# %% [markdown]
# Push this document to your fork if you like, but you must also upload it to the iLearn **Week 14 Final Grade Claim** item.
#
# Upload it by 8:00am, Monday 5 April 2021, if your grade claim is scheduled for Monday. Otherwise, submit it by 8:00am, Tuesday 6 April 2021.

# %% [markdown]
# ## Creating Links to Cells in other Notebooks

# %% [markdown]
# This image shows where to find the "Link to Cell" tool.
#
# ![link-to-cell.png](data:image/png;base64,...)

# %% [markdown]
# Find the cell in another notebook that you want to link to in your final grade claim document.
#
# Click the "Link to cell" tool and you'll see a dialogue box pop up that looks something like this:

# %% [markdown]
# ![link-to-cell-dialogue.png](data:image/png;base64,...)

# %% [markdown]
# Click the "Copy" button in the upper-right corner of this dialogue box and paste the link in your final grade claim document.
#
# It will look something like this:
#
# ```https://colab.research.google.com/github/byui-cse/cse380-notebooks/blob/master/13_2_Ponder_and_Prove_Many_Things.ipynb#scrollTo=fGZ9lZCP9xWC&line=1&uniqifier=1```
#
# only with your Github username in place of ```byui-cse```.
#
# Put the text of the link in square brackets [] followed by the actual URL in parentheses (). The text should be a brief description of what is at the target of the link.

# %% [markdown]
# ## During your five minutes

# %% [markdown]
# The plan is for you to have your document loaded up in your browser ready to walk me through it, in this order:
#
# 1. Show me your flowchart decision path, with the **leaf $\equiv$ claimed grade** highlighted.
# 2. Show me and take a minute each to talk about your evidences (Top 3 or 2) and your **previously recorded** above and beyond behaviors.
#
# Test your links beforehand to make sure they work! A smooth transition between the different items you're presenting is the goal.
